# %%
import sys
# !{sys.executable} -m pip install seaborn

import pandas as pd
import numpy as np
import seaborn as sb
All_data = pd.read_pickle('tfa_working_ver_1')
All_data = All_data.dropna(how ='any')
All_data
# Out:
# ...
#     100% |████████████████████████████████| 215kB 25.7MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 12.9MB 2.5MB/s eta 0:00:01    92% |█████████████████████████████▋  | 11.9MB 48.8MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 31.2MB 1.1MB/s eta 0:00:01   14% |████▊                           | 4.6MB 47.0MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 952kB 11.8MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 19.3MB/s ta 0:00:01
# ...
#     player_rank              player pos  age  games  games_started  \
# 0            65        aaron brooks  PG   33     32              1
# 1           179        aaron gordon  PF   22     58             57
# 2           363         abdel nader  SF   24     48              1
# 3           227          al horford   C   31     72             72
# 4           250        al jefferson   C   33     36              1
# 6            78          alec burks  SG   26     64              1
# ...

# %%
list(All_data.columns.values)
# Out:
# ['player_rank',
#  'player',
#  'pos',
#  'age',
#  'games',
#  'games_started',
#  'min_per_game',
#  'field_goals',
#  'field_goals_attempts',
#  'field_goals_pct',
#  '3points',
#  '3points_attempts',
#  '3points_pct',
#  '2points',
#  '2points_attempts',
#  '2points_pct',
#  'efg_pct',
#  'free_throws',
#  'free_throws_attempts',
#  'free_throws_pct',
#  'orb',
#  'drb',
#  'trb',
#  'assists',
#  'steals',
#  'blocks',
#  'turnovers',
#  'personal_fouls',
#  'points_per_game',
#  'year',
#  'salary',
#  'new_pos',
#  'team_id',
#  'team_points',
#  'team',
#  'team_rank']

# %%
# Linear regression on variables with no missing values
# Note that some columns have missing values 

import statsmodels.api as sm

X = All_data[['age', 'games', 'games_started', 'min_per_game', 'field_goals', 'field_goals_attempts', '2points', '2points_attempts', '2points_pct', \
              '3points', '3points_attempts', '3points_pct', 'efg_pct', 'free_throws', 'orb','drb', 'trb', 'assists', 'steals', 'blocks','free_throws_attempts', \
              'turnovers', 'personal_fouls', 'points_per_game', 'team_points']] 
## independent variables
y = All_data['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.593
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                     22.33
# Date:                Sun, 02 Dec 2018   Prob (F-statistic):           7.99e-60
# Time:                        02:24:34   Log-Likelihood:                -6868.1
# No. Observations:                 409   AIC:                         1.379e+04
# Df Residuals:                     383   BIC:                         1.389e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Linear regression on variables taken from Ankit...I don't fully understand the selection process yet

import statsmodels.api as sm

X = All_data[['age', 'games', 'games_started', 'min_per_game', 'field_goals', 'field_goals_attempts', '2points', '2points_attempts', \
              'free_throws', 'free_throws_attempts', 'turnovers', 'points_per_game']]  ## independent variables

y = All_data['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.567
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     43.26
# Date:                Sat, 01 Dec 2018   Prob (F-statistic):           1.54e-64
# Time:                        19:10:13   Log-Likelihood:                -6880.6
# No. Observations:                 409   AIC:                         1.379e+04
# Df Residuals:                     396   BIC:                         1.384e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Linear regression on variables that I think are good ones qualitatively


import statsmodels.api as sm

X = All_data[['age', 'games', 'games_started', 'min_per_game', '3points', 'field_goals', 'orb', \
              'free_throws_attempts', 'blocks', 'points_per_game']]  ## independent variables

y = All_data['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                     51.35
# Date:                Sat, 01 Dec 2018   Prob (F-statistic):           1.71e-65
# Time:                        19:10:18   Log-Likelihood:                -6882.5
# No. Observations:                 409   AIC:                         1.379e+04
# Df Residuals:                     398   BIC:                         1.383e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
# Linear regression on variables that are significant on 10% level from the first regression

import statsmodels.api as sm

X = All_data[['age', 'games', 'games_started', '2points', '3points', 'trb', 'assists', \
              'turnovers', 'personal_fouls', 'team_points']]  ## independent variables

y = All_data['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     50.88
# Date:                Sat, 01 Dec 2018   Prob (F-statistic):           4.72e-65
# Time:                        19:11:30   Log-Likelihood:                -6883.5
# No. Observations:                 409   AIC:                         1.379e+04
# Df Residuals:                     398   BIC:                         1.383e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
#95% level

import statsmodels.api as sm

X = All_data[['age', 'games', 'games_started', '2points', '3points', 'trb', 'assists']]  ## independent variables

y = All_data['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     69.41
# Date:                Sat, 01 Dec 2018   Prob (F-statistic):           3.01e-65
# Time:                        19:12:22   Log-Likelihood:                -6889.6
# No. Observations:                 409   AIC:                         1.380e+04
# Df Residuals:                     401   BIC:                         1.383e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
All_data_star = All_data[(All_data["games"]>=50) &
                   ((All_data["points_per_game"] >= 20) | 
                    (All_data["trb"] >= 8) & (All_data["points_per_game"] >= 10) |
                     (All_data["assists"] >= 10) & (All_data["points_per_game"] >= 10) |
                      (All_data["assists"] >= 5) & (All_data["points_per_game"] >= 15) & (All_data["trb"] >= 5) |
                       (All_data["points_per_game"] >= 15) & (All_data['3points_pct'] >= 0.4) & (All_data['3points'] >= 2))]
                

All_data_star
# Out:
#     player_rank                 player pos  age  games  games_started  \
# 13          140         andre drummond   C   24     78             78
# 20          122          anthony davis  PF   24     75             75
# 28          450            ben simmons  PG   21     81             81
# 30          191          blake griffin  PF   28     58             58
# 36           37           bradley beal  SG   24     82             82
# 56          396             chris paul  PG   32     58             58
# 57          322            cj mccollum  SG   26     81             81
# 59           85           clint capela   C   23     74             74
# 68          298         damian lillard  PG   27     73             73
# 91          130          demar derozan  SG   28     80             80
# 102          58           devin booker  SG   21     54             54
# 112         343       donovan mitchell  SG   21     79             71
# ...

# %%
All_data_3points = All_data[(All_data["games"] >= 50) & (All_data['3points_pct'] >= 0.37) & (All_data['3points'] >= 2)]
All_data_3points
# Out:
#     player_rank                   player pos  age  games  games_started  \
# 11          114             allen crabbe  SG   25     75             68
# 21          482         anthony tolliver  PF   32     79             14
# 24          428            austin rivers  SG   25     61             59
# 36           37             bradley beal  SG   24     82             82
# 45          215              buddy hield  SG   24     80             12
# 56          396               chris paul  PG   32     58             58
# 57          322              cj mccollum  SG   26     81             81
# 77          440              dario saric  PF   23     78             73
# 93           86          demarre carroll  SF   31     73             73
# 102          58             devin booker  SG   21     54             54
# 131         163            evan fournier  SF   25     57             57
# 139         198              gary harris  SG   23     67             65
# ...

# %%
All_data_superstar = All_data[(All_data["games"]>=50) &
                              ((All_data["points_per_game"] >= 25) | 
                               (All_data["assists"] >= 10) & (All_data["points_per_game"] >= 10) |
                               (All_data["trb"] >= 10) & (All_data["points_per_game"] >= 15) |
                               (All_data["assists"] >= 4) & (All_data["points_per_game"] >= 20) & (All_data["trb"] >= 4))]



All_data_superstar
# Out:
#     player_rank                 player pos  age  games  games_started  \
# 13          140         andre drummond   C   24     78             78
# 20          122          anthony davis  PF   24     75             75
# 30          191          blake griffin  PF   28     58             58
# 36           37           bradley beal  SG   24     82             82
# 68          298         damian lillard  PG   27     73             73
# 102          58           devin booker  SG   21     54             54
# 118         229          dwight howard   C   32     81             81
# 144          16  giannis antetokounmpo  PF   23     75             75
# 174         194           james harden  SG   28     72             72
# 197          79           jimmy butler  SG   28     59             59
# 207         147            joel embiid   C   23     63             63
# 240         483      karlanthony towns   C   22     82             82
# ...

# %%
All_data_centers =  All_data[(All_data["games"] >= 50) & (All_data['points_per_game'] >= 8) & (All_data['trb'] >= 6) & (All_data['pos'] == 'C')]
                             
All_data_centers
# Out:
#     player_rank              player pos  age  games  games_started  \
# 3           227          al horford   C   31     72             72
# 8           292            alex len   C   24     69             13
# 13          140      andre drummond   C   24     78             78
# 59           85        clint capela   C   23     74             74
# 98          155      derrick favors   C   26     77             77
# 104         125      dewayne dedmon   C   28     62             46
# 111         438    domantas sabonis   C   21     74             19
# 118         229       dwight howard   C   32     81             81
# 125         271         enes kanter   C   25     71             71
# 152         513    hassan whiteside   C   28     54             54
# 207         147         joel embiid   C   23     63             63
# 210         210         john henson   C   27     76             69
# 215         489   jonas valanciunas   C   25     77             77
# ...

# %%
All_data_fouls =  All_data[(All_data["games"] >= 50) & (All_data['free_throws_attempts'] >= 4) & (All_data['free_throws_pct'] >= 0.75)]
                             
All_data_fouls
# Out:
#     player_rank                  player pos  age  games  games_started  \
# 20          122           anthony davis  PF   24     75             75
# 30          191           blake griffin  PF   28     58             58
# 36           37            bradley beal  SG   24     82             82
# 68          298          damian lillard  PG   27     73             73
# 91          130           demar derozan  SG   28     80             80
# 95          442         dennis schroder  PG   24     67             67
# 102          58            devin booker  SG   21     54             54
# 126          52            eric bledsoe  PG   28     74             74
# 144          16   giannis antetokounmpo  PF   23     75             75
# 151          31         harrison barnes  PF   25     77             77
# 174         194            james harden  SG   28     72             72
# 197          79            jimmy butler  SG   28     59             59
# ...

# %%
import statsmodels.api as sm

X = All_data_star[['age', 'games', 'games_started', 'min_per_game', 'field_goals', 'field_goals_attempts', '2points', '2points_attempts', '2points_pct', \
              '3points', '3points_attempts', '3points_pct', 'efg_pct', 'free_throws', 'orb','drb', 'trb', 'assists', 'steals', 'blocks','free_throws_attempts', \
              'turnovers', 'personal_fouls', 'points_per_game', 'team_points', 'personal_fouls']] 
## independent variables
y = All_data_star['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     2.415
# Date:                Sun, 02 Dec 2018   Prob (F-statistic):             0.0240
# Time:                        02:17:08   Log-Likelihood:                -771.11
# No. Observations:                  46   AIC:                             1594.
# Df Residuals:                      20   BIC:                             1642.
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

X = All_data_star[['age', 'games', 'games_started']] 
## independent variables
y = All_data_star['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     12.87
# Date:                Sun, 02 Dec 2018   Prob (F-statistic):           4.22e-06
# Time:                        02:18:10   Log-Likelihood:                -788.11
# No. Observations:                  46   AIC:                             1584.
# Df Residuals:                      42   BIC:                             1592.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

All_data_superstar[All_data_superstar == np.inf] = np.nan
All_data_superstar.fillna(method='ffill')

X = All_data_superstar[['age', 'games', 'games_started', 'min_per_game', 'field_goals', 'field_goals_attempts', '2points', '2points_attempts', '2points_pct', \
              '3points', '3points_attempts', '3points_pct', 'efg_pct', 'free_throws', 'orb','drb', 'trb', 'assists', 'steals', 'blocks','free_throws_attempts', \
              'turnovers', 'personal_fouls', 'points_per_game', 'team_points', 'personal_fouls','salary']] 


y = All_data_superstar['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X1).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-e03bfd472b89> in <module>
#      16
#      17 model = sm.OLS(y, X1).fit() ## sm.OLS(output, input)
# ---> 18 predictions = model.predict(X)
#      19
#      20 model.summary()
#
# /usr/local/lib/python3.6/site-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#     852
#     853         predict_results = self.model.predict(self.params, exog, *args,
# --> 854                                              **kwargs)
#     855
# ...

# %%
import statsmodels.api as sm

X = All_data_3points[['age', 'games', 'games_started', 'min_per_game', 'field_goals', 'field_goals_attempts', '2points', '2points_attempts', '2points_pct', \
              '3points', '3points_attempts', '3points_pct', 'efg_pct', 'free_throws', 'orb','drb', 'trb', 'assists', 'steals', 'blocks','free_throws_attempts', \
              'turnovers', 'personal_fouls', 'points_per_game', 'team_points']] 
## independent variables
y = All_data_3points['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     2.382
# Date:                Sun, 02 Dec 2018   Prob (F-statistic):             0.0765
# Time:                        02:23:22   Log-Likelihood:                -592.73
# No. Observations:                  36   AIC:                             1237.
# Df Residuals:                      10   BIC:                             1279.
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

X = All_data_centers[['age', 'games', 'games_started', 'min_per_game', 'field_goals', 'field_goals_attempts', '2points', '2points_attempts', '2points_pct', \
              '3points', '3points_attempts', '3points_pct', 'efg_pct', 'free_throws', 'orb','drb', 'trb', 'assists', 'steals', 'blocks','free_throws_attempts', \
              'turnovers', 'personal_fouls', 'points_per_game', 'team_points']] 
## independent variables
y = All_data_centers['salary']  ## Dependent variable
X = sm.add_constant(X)  ## let's add an intercept (beta_0) to our model

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                     0.000
# Date:                Sun, 02 Dec 2018   Prob (F-statistic):                nan
# Time:                        02:24:20   Log-Likelihood:                 307.81
# No. Observations:                  26   AIC:                            -563.6
# Df Residuals:                       0   BIC:                            -530.9
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
All_data[All_data["player"] in ['', ]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e3ad4accf94e> in <module>
# ----> 1 All_data[All_data["player"] in ['', ]]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
