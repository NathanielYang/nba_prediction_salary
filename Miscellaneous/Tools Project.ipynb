# %%
import pandas as pd
tools_data = pd.read_pickle('player_stats_year_wise.pkl')
tools_data
# Out:
#      rank                 player   pos age team_id games games_started  \
# 0       1          Arron Afflalo    SG  24     DEN    82            75
# 1       2          Alexis Ajinca     C  21     CHA     6             0
# 2       3      LaMarcus Aldridge    PF  24     POR    78            78
# 3       4          Joe Alexander    SF  23     CHI     8             0
# 4       5            Malik Allen    PF  31     DEN    51             3
# 5       6             Ray Allen*    SG  34     BOS    80            80
# 6       7             Tony Allen    SG  28     BOS    54             8
# 7       8           Rafer Alston    PG  33     TOT    52            38
# 8       8           Rafer Alston    PG  33     NJN    27            13
# 9       8           Rafer Alston    PG  33     MIA    25            25
# 10      9           Lou Amundson    PF  27     PHO    79             0
# 11     10         Chris Andersen    PF  31     DEN    76             0
# ...
