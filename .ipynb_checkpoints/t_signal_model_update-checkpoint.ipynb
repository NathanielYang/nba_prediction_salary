# %% [markdown]
# ### 1. Import and Clean data

# %%
# try change
import pandas as pd
import numpy as np
from sklearn import preprocessing

import seaborn as sb

import statsmodels.api as sm
import datetime
from sklearn.metrics import r2_score
# %matplotlib inline

#data = pd.read_pickle('player_stats_year_wise.pkl')
#data
data1617 = pd.read_pickle('tfa_working_ver_1_2016-17')
data1718 = pd.read_pickle('tfa_working_ver_1')
data1819 = pd.read_pickle('tfa_working_ver_1_2018-19')
data1617
# Out:
#     player_rank              player pos  age  games  games_started  \
# 0            58        aaron brooks  PG   32     65              0
# 1           157        aaron gordon  SF   21     80             72
# 2           181      aaron harrison  SG   22      5              0
# 3           352       adreian payne  PF   25     18              0
# 4           170          aj hammons   C   24     22              0
# 5           203          al horford   C   30     68             68
# 6           221        al jefferson   C   32     66              1
# 7            12       alan anderson  SF   34     30              0
# 8           464       alan williams   C   24     47              0
# 9            65          alec burks  SG   25     42              0
# 10            1        alex abrines  SG   23     68              6
# 11          260            alex len   C   23     77             34
# 12          366      alex poythress  PF   23      6              1
# 13            5       alexis ajinca   C   28     39             15
# 14           10      alfarouq aminu  PF   26     61             25
# 15           92        allen crabbe  SG   24     79              7
# 16          149          alonzo gee  SF   29     13              0
# 17          226        amir johnson  PF   29     80             77
# 18          443    anderson varejao   C   34     14              1
# 19          115      andre drummond   C   23     81             81
# 20          211      andre iguodala  SF   33     76              0
# 21          377      andre roberson  SF   25     79             79
# 22           51        andrew bogut   C   32     27             21
# 23          182     andrew harrison  PG   22     72             18
# 24          327    andrew nicholson  PF   27     38              0
# 25          462      andrew wiggins  SF   21     82             82
# 26           42     anthony bennett  PF   23     23              1
# 27           59       anthony brown  SF   24     11              0
# 28          100       anthony davis   C   23     75             75
# 29          312      anthony morrow  SG   31     49              7
# ..          ...                 ...  ..  ...    ...            ...
# 456          64          trey burke  PG   24     57              0
# 457         277          trey lyles  PF   21     71              4
# 458         428    tristan thompson   C   25     78             78
# 459          99        troy daniels  SG   25     67              3
# 460         470       troy williams  SF   22     30             16
# 461         256           ty lawson  PG   29     69             24
# 462         126         tyler ennis  PG   22     53              2
# 463         231       tyler johnson  PG   24     73              0
# 464         438          tyler ulis  PG   21     61             15
# 465         483        tyler zeller   C   27     51              5
# 466         127        tyreke evans  SF   27     40              6
# 467          77      tyson chandler   C   34     47             46
# 468         239          tyus jones  PG   20     60              0
# 469         183       udonis haslem   C   36     16              0
# 470         339      victor oladipo  SG   24     67             67
# 471          73        vince carter  SF   40     73             15
# 472          25        wade baldwin  PG   20     33              1
# 473         122     wayne ellington  SG   29     62             13
# 474         398        wayne selden  SG   22     14              5
# 475         232      wesley johnson  SF   29     68              3
# 476         284     wesley matthews  SG   30     73             73
# 477          30         will barton  SG   26     60             19
# 478          76  willie cauleystein   C   23     75             21
# 479         373         willie reed   C   26     71              5
# 480         189   willy hernangomez   C   22     72             22
# 481          78     wilson chandler  SF   29     71             33
# 482         135        yogi ferrell  PG   23     46             29
# 483         255         zach lavine  SG   21     47             47
# 484         371       zach randolph  PF   35     73              5
# 485         344       zaza pachulia   C   32     70             70
#
#      min_per_game  field_goals  field_goals_attempts  field_goals_pct  \
# 0            13.8          1.9                   4.6            0.403
# 1            28.7          4.9                  10.8            0.454
# 2             3.4          0.0                   0.8            0.000
# 3             7.5          1.3                   3.0            0.426
# 4             7.4          0.8                   1.9            0.405
# 5            32.3          5.6                  11.8            0.473
# 6            14.1          3.6                   7.1            0.499
# 7            10.3          1.0                   2.7            0.375
# 8            15.1          2.9                   5.7            0.517
# 9            15.5          2.4                   5.9            0.399
# 10           15.5          2.0                   5.0            0.393
# 11           20.3          3.0                   6.0            0.497
# 12           26.2          4.2                   9.0            0.463
# 13           15.0          2.3                   4.6            0.500
# 14           29.1          3.0                   7.6            0.393
# 15           28.5          3.8                   8.2            0.468
# 16            6.8          0.2                   1.1            0.214
# 17           20.1          2.7                   4.6            0.576
# 18            6.6          0.4                   1.0            0.357
# 19           29.7          6.0                  11.2            0.530
# 20           26.3          2.9                   5.5            0.528
# 21           30.1          2.7                   5.9            0.464
# 22           21.6          1.4                   3.0            0.469
# 23           20.5          1.6                   5.0            0.325
# 24            9.0          1.1                   2.9            0.387
# 25           37.2          8.6                  19.1            0.452
# 26           11.5          1.7                   4.0            0.413
# 27           14.5          1.6                   4.5            0.360
# 28           36.1         10.3                  20.3            0.505
# 29           14.6          2.0                   5.1            0.389
# ..            ...          ...                   ...              ...
# 456          12.3          2.0                   4.5            0.455
# 457          16.3          2.2                   6.2            0.362
# 458          29.9          3.4                   5.6            0.600
# 459          17.7          2.8                   7.4            0.374
# 460          18.6          2.4                   5.6            0.437
# 461          25.1          3.4                   7.6            0.454
# 462          11.1          1.7                   3.9            0.433
# 463          29.8          4.9                  11.3            0.433
# 464          18.4          3.0                   7.2            0.421
# 465          10.3          1.5                   3.1            0.494
# 466          19.7          3.8                   9.3            0.405
# 467          27.6          3.3                   4.9            0.671
# 468          12.9          1.3                   3.0            0.414
# 469           8.1          0.7                   1.4            0.478
# 470          33.2          6.1                  13.9            0.442
# 471          24.6          2.6                   6.7            0.394
# 472          12.3          1.1                   3.5            0.313
# 473          24.2          3.7                   9.0            0.416
# 474          16.9          1.8                   4.1            0.431
# 475          11.9          1.1                   2.9            0.365
# 476          34.2          4.6                  11.6            0.393
# 477          28.4          4.9                  11.1            0.443
# 478          18.9          3.4                   6.4            0.530
# 479          14.5          2.3                   4.0            0.568
# 480          18.4          3.4                   6.5            0.529
# 481          30.9          6.1                  13.2            0.461
# 482          26.0          3.5                   8.6            0.406
# 483          37.2          6.9                  15.1            0.459
# 484          24.5          5.9                  13.2            0.449
# 485          18.1          2.3                   4.4            0.534
#
#        ...      turnovers  personal_fouls  points_per_game  year      salary  \
# 0      ...            1.0             1.4              5.0  2017   2700000.0
# 1      ...            1.1             2.2             12.7  2017   4351320.0
# 2      ...            0.0             0.4              0.2  2017    375579.0
# 481    ...            1.6             2.4             15.7  2017  11200000.0
# 482    ...            1.5             2.0             10.0  2017    239767.0
# 483    ...            1.8             2.2             18.9  2017   2240880.0
# 484    ...            1.4             1.9             14.1  2017  10361445.0
# 485    ...            1.2             2.4              6.1  2017   2898000.0
#
#      team_id  new_pos  team_points                    team  team_rank
# 0        IND     back        0.512          Indiana Pacers         13
# 1        ORL    front        0.354           Orlando Magic         26
# 2        CHO     back        0.439       Charlotte Hornets         20
# 3        MIN    front        0.378  Minnesota Timberwolves         24
# 4        DAL    front        0.402        Dallas Mavericks         22
# 5        BOS    front        0.646          Boston Celtics          4
# 6        IND    front        0.512          Indiana Pacers         13
# 7        LAC    front        0.622    Los Angeles Clippers          8
# 8        PHO    front        0.293            Phoenix Suns         29
# 9        UTA     back        0.622               Utah Jazz          7
# 10       OKC     back        0.573   Oklahoma City Thunder         10
# 11       PHO    front        0.293            Phoenix Suns         29
# 12       PHI    front        0.341      Philadelphia 76ers         27
# 13       NOP    front        0.415    New Orleans Pelicans         21
# 14       POR    front        0.500  Portland Trail Blazers         15
# 15       POR     back        0.500  Portland Trail Blazers         15
# 16       DEN    front        0.488          Denver Nuggets         18
# 17       BOS    front        0.646          Boston Celtics          4
# 18       GSW    front        0.817   Golden State Warriors          1
# 19       DET    front        0.451         Detroit Pistons         19
# 20       GSW    front        0.817   Golden State Warriors          1
# 21       OKC    front        0.573   Oklahoma City Thunder         10
# 22       DAL    front        0.402        Dallas Mavericks         22
# 23       MEM     back        0.524       Memphis Grizzlies         12
# 24       WAS    front        0.598      Washington Wizards          9
# 25       MIN    front        0.378  Minnesota Timberwolves         24
# 26       BRK    front        0.244           Brooklyn Nets         30
# 27       NOP    front        0.415    New Orleans Pelicans         21
# 28       NOP    front        0.415    New Orleans Pelicans         21
# 29       OKC     back        0.573   Oklahoma City Thunder         10
# ..       ...      ...          ...                     ...        ...
# 456      WAS     back        0.598      Washington Wizards          9
# 457      UTA    front        0.622               Utah Jazz          7
# 458      CLE    front        0.622     Cleveland Cavaliers          6
# 459      MEM     back        0.524       Memphis Grizzlies         12
# 460      MEM    front        0.524       Memphis Grizzlies         12
# 461      SAC     back        0.390        Sacramento Kings         23
# 462      HOU     back        0.671         Houston Rockets          3
# 463      MIA     back        0.500              Miami Heat         16
# 464      PHO     back        0.293            Phoenix Suns         29
# 465      BOS    front        0.646          Boston Celtics          4
# 466      NOP    front        0.415    New Orleans Pelicans         21
# 467      PHO    front        0.293            Phoenix Suns         29
# 468      MIN     back        0.378  Minnesota Timberwolves         24
# 469      MIA    front        0.500              Miami Heat         16
# 470      OKC     back        0.573   Oklahoma City Thunder         10
# 471      MEM    front        0.524       Memphis Grizzlies         12
# 472      MEM     back        0.524       Memphis Grizzlies         12
# 473      MIA     back        0.500              Miami Heat         16
# 474      MEM     back        0.524       Memphis Grizzlies         12
# 475      LAC    front        0.622    Los Angeles Clippers          8
# 476      DAL     back        0.402        Dallas Mavericks         22
# 477      DEN     back        0.488          Denver Nuggets         18
# 478      SAC    front        0.390        Sacramento Kings         23
# 479      MIA    front        0.500              Miami Heat         16
# 480      NYK    front        0.378         New York Knicks         25
# 481      DEN    front        0.488          Denver Nuggets         18
# 482      DAL     back        0.402        Dallas Mavericks         22
# 483      MIN     back        0.378  Minnesota Timberwolves         24
# 484      MEM    front        0.524       Memphis Grizzlies         12
# 485      GSW    front        0.817   Golden State Warriors          1
#
# [486 rows x 36 columns]

# %%
def data_clean(data):
    df = data.set_index(data.iloc[:,1]).drop(columns = 'player')
    ori_factors = df.loc[:,['games', 'games_started','min_per_game','field_goals_pct','3points_pct','2points_pct', 'efg_pct','free_throws_pct','trb','assists', 'steals', 'blocks', 'turnovers', 'personal_fouls','points_per_game', 'team_points']].dropna()
    factors = pd.DataFrame(preprocessing.scale(ori_factors))
    factors.columns = ori_factors.columns
    factors.index = ori_factors.index
    return factors

def salary_clean(data):
    df = data.set_index(data.iloc[:,1]).drop(columns = 'player').dropna()
    salary = df.ix[:]['salary']
    salary = pd.DataFrame(preprocessing.scale(salary))
    salary.index = df.index
    return salary, df.ix[:]['salary']

def salary_delta(salary, new_salary):
    df = pd.concat([new_salary, salary],axis = 1).dropna()
    delta = df.iloc[:,0] - df.iloc[:,1]
    return delta

# %%
factors1617 = data_clean(data1617)
factors1718 = data_clean(data1718)
factors1819 = data_clean(data1819)

(salary17, ori_salary17) = salary_clean(data1617)
(salary18, ori_salary18) = salary_clean(data1718)
salary_delta18 = salary_delta(ori_salary17, ori_salary18)
# salary_delta18
factors1718
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # This is added back by InteractiveShellApp.init_path()
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %% [markdown]
# ### 2. Regression Analysis

# %%
# factors, salary are operated data

def regression(factors, salary):
    if isinstance(factors, pd.Series): factors = pd.DataFrame(factors)
    
    factor_index = list(factors.columns)
    stat_value = pd.Series(factor_index)

    corr_single_list = []
    t_single_list = []
    rsquare_single_list = []
    
    row = len(factors)
    col = len(factors.columns)
    
    for s in range(col):
        xy = pd.concat([salary, factors.iloc[:,s]], axis=1).dropna()
        # print(salary,factors.iloc[:,s])
        # corr between single x and y
        corr = xy.corr().iloc[0,1]
        y = xy.iloc[:,0]
        x = xy.iloc[:,1]
        beta = sum((x-np.mean(x))*(y-np.mean(y)))/sum((x-np.mean(x))**2) 
        const = np.mean(y)-beta*np.mean(x)          
        # variance  
        var=sum((y-const-beta*x)**2)/(len(y)-2)
        # std. var  
        sigma=np.sqrt(var) 
        # r_square
        rsquare = r2_score(y, (const+beta*x))
        #t-value  
        t=beta*np.sqrt(sum((x-np.mean(x))**2))/sigma
        
        t_single_list.append(t)
        corr_single_list.append(corr)
        rsquare_single_list.append(rsquare)
    
    t_value = pd.Series(t_single_list)        
    corr_value= pd.Series(corr_single_list)
    rsquare_value = pd.Series(rsquare_single_list)

    stat_value = pd.concat([stat_value,t_value, corr_value, rsquare_value],axis = 1)
    stat_value.columns=['factors', 't-value', 'correlation', 'r-square']
    stat_value=stat_value.set_index('factors')
    
    return stat_value, beta, const

# %%
(stat_value1617, beta, const) = regression(factors1617, salary17)
(stat_value1718, beta, const) = regression(factors1718, salary18)
pd.concat([stat_value1617, stat_value1718],axis=1)
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %% [markdown]
# ### 3. Prediction Analysis (using pre_data)

# %%
def t_signal(stat_value):
    t_table = stat_value.iloc[:,0] # fetch t-values

    num = len(t_table)
    t_signal = pd.Series(np.zeros(num), index=t_table.index)

    for i in range(num):
        if t_table[i] >= 5: t_signal[i] = 1             # t-value > 0: positive factor，+1
        elif t_table[i] <= -5: t_signal[i] = -1        # t-value < 0: negative factor，+1
        else: t_signal[i] = 0
    return t_signal


def final_score(factors, pre_factors, t_signal):            
    name_index = list(pre_factors.index & factors.index)       # players appear both in 2017 and 2018
    score = []
    for name in name_index:
        delta = pre_factors.loc[name] - factors.loc[name]
        score.append(sum(np.sign(delta) * t_signal))
    
    final_score = pd.Series(score, index = name_index)
    return final_score

# %%
t_signal1617 = t_signal(stat_value1617)
t_signal1718 = t_signal(stat_value1718)

final_score1617 = final_score(factors1617,factors1718,t_signal1617)
final_score1718 = final_score(factors1718,factors1819,t_signal1718)
pd.concat([final_score1718, final_score1617],axis=1).dropna()

# %%
temp = pd.concat([salary_delta18,final_score1617],axis =1).dropna()
test = pd.DataFrame(preprocessing.scale(temp))
print(regression(test.iloc[:,1],test.iloc[:,0]))
test.plot()
#pd.concat([ori_salary18,ori_salary17,salary_delta18],axis =1).dropna()
# Out:
# (          t-value  correlation  r-square
# factors
# 1        0.192823     0.010582  0.000112, 0.010581963263967915, -3.222497810576139e-17)
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
(stat, beta, const) = regression(final_score1617,salary18)
new_delta = const + beta*final_score1718
new_salary = (new_delta*np.std(ori_salary18)+ori_salary18).dropna()

#+ np.mean(ori_salary18)
test = pd.concat([new_salary,ori_salary18, new_delta,final_score1718],axis = 1).dropna()
test.columns = ['new_salary','salary2018','delta','score']
test
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#                           new_salary  salary2018     delta  score
# aaron gordon            5.859117e+06   5504420.0  0.047648    3.0
# al horford              2.939543e+07  27734405.0  0.223135  -13.0
# alec burks              1.136349e+07  10845506.0  0.069584    1.0
# alex abrines            5.753114e+06   5725000.0  0.003777    7.0
# alex len                4.542296e+06   4187599.0  0.047648    3.0
# alfarouq aminu          8.653480e+06   7319035.0  0.179263   -9.0
# alfonzo mckinnie        1.905635e+05    815615.0 -0.083966   15.0
# allen crabbe            2.148340e+07  19332500.0  0.288942  -19.0
# amir johnson            1.249774e+07  11000000.0  0.201199  -11.0
# andre drummond          2.478337e+07  23775506.0  0.135391   -5.0
# andre iguodala          1.680243e+07  14814815.0  0.267006  -17.0
# andrew harrison         3.626804e+06   1312611.0  0.310878  -21.0
# andrew wiggins          9.398641e+06   7574322.0  0.245070  -15.0
# anthony davis           2.494666e+07  23775506.0  0.157327   -7.0
